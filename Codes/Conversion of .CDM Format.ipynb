# %% [markdown]
# # Convert .DCM files into Normal format

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Untitled.ipynb']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Desktop\\Parkinson\\Codes'

# %%
os.chdir('C:\\Users\\hp\\Desktop\\Parkinson')
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Codes',
#  'data',
#  'Datasets',
#  'Final Docs',
#  'himashu paper.pdf',
#  'Major',
#  'PPMI Dataset',
#  'Substantia nigra.png',
#  'Summary(A Deep Learning approach for Parkinson’s disease diagnosis from EEG Signals).docx',
#  'Summary(An Improved Approach for Prediction of Parkinson’s Disease using Machine LearningTechniques).docx',
#  'Summary(Paper 3).docx',
#  "Summary(Refining diagnosis of Parkinson's disease with deep learning-basedinterpretation of dopamine transporter imaging).docx",
#  'Thumbs.db']

# %%
for i in os.listdir():
    path='C:\\Users\\hp\\Desktop\\Parkinson\\PPMI Dataset\\MRI Dataset\\PPMI\\3001\\AX_T2_AC-PC_line_Entire_Brain\\2011-03-02_11_28_01.0\\S102127'
    os.chdir(path)
    print("FOLDER=",i)
    os.listdir()
    #os.getcwd()
    #os.chdir(path+"\\"+i)
    #if len(os.listdir())>0:
    #    print("SUBDIRECTORIES:",os.listdir())
# Out:
# FOLDER= .ipynb_checkpoints
# FOLDER= Codes
# FOLDER= data
# FOLDER= Datasets
# FOLDER= Final Docs
# FOLDER= himashu paper.pdf
# FOLDER= Major
# FOLDER= PPMI Dataset
# FOLDER= Substantia nigra.png
# FOLDER= Summary(A Deep Learning approach for Parkinson’s disease diagnosis from EEG Signals).docx
# FOLDER= Summary(An Improved Approach for Prediction of Parkinson’s Disease using Machine LearningTechniques).docx
# FOLDER= Summary(Paper 3).docx
# FOLDER= Summary(Refining diagnosis of Parkinson's disease with deep learning-basedinterpretation of dopamine transporter imaging).docx
# FOLDER= Thumbs.db

# %% [markdown]
# # 1.)Convert .dcm file to IMAGE

# %%
import pydicom as dicom
import matplotlib.pyplot as pylab
#import Image

dFile=dicom.read_file("PPMI_3001_MR_AX_T2_AC-PC_line_Entire_Brain__br_raw_20110322144205058_53_S102127_I224573.dcm") #path to file
pylab.imshow(dFile.pixel_array,cmap=pylab.cm.bone) # pylab readings and conversion
pylab.show()

# %% [markdown]
# # 2.)Convert .dcm file to MetaData

# %%
import pydicom
from pydicom.data import get_testdata_files
import numpy as np
file="PPMI_3001_MR_AX_T2_AC-PC_line_Entire_Brain__br_raw_20110322144205058_53_S102127_I224573.dcm"  
os.listdir()
ds = pydicom.dcmread(file)  # plan dataset
len(ds.dir())
# Out:
# 92

# %%
ds
# Out:
# (0008, 0000) Group Length                        UL: 682
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'OTHER']
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 2.16.124.113543.6006.99.0247245531011795643
# (0008, 0020) Study Date                          DA: '20110302'
# (0008, 0021) Series Date                         DA: '20110302'
# (0008, 0022) Acquisition Date                    DA: '20110302'
# (0008, 0023) Content Date                        DA: '20110302'
# (0008, 0030) Study Time                          TM: '112801'
# (0008, 0031) Series Time                         TM: '115440'
# (0008, 0032) Acquisition Time                    TM: '115440'
# (0008, 0033) Content Time                        TM: '115440'
# (0008, 0050) Accession Number                    SH: '7988755'
# ...

# %%
print(ds.AccessionNumber,ds.PatientName)
# Out:
# 7988755 DE-IDENTIFIED

# %%
ds.dir("pixel")
# Out:
# ['LargestImagePixelValue',
#  'PixelBandwidth',
#  'PixelData',
#  'PixelRepresentation',
#  'PixelSpacing',
#  'SamplesPerPixel',
#  'SmallestImagePixelValue']

# %%
arr=np.array(ds.PixelData)
arr
# Out:
# array(b'\x
# ...
